# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from xgboost.sklearn import XGBClassifier

# %% [markdown]
# ## Inspecting data

# %%
seed = 12

df = pd.read_stata('../data/HCMST 2017 fresh sample for public sharing draft v1.1.dta')
df.head()
# Out:
#    CaseID  CASEID_NEW      qflag  weight1  weight1_freqwt  weight2  weight1a  \
# 0       2     2014039  Qualified      NaN             NaN   0.8945       NaN
# 1       3     2019003  Qualified   0.9078         71115.0      NaN    0.9026
# 2       5     2145527  Qualified   0.7205         56442.0      NaN    0.7164
# 3       6     2648857  Qualified   1.2597         98682.0   1.3507    1.2524
# 4       7     2623465  Qualified   0.8686         68044.0      NaN    0.8636
#
#    weight1a_freqwt  weight_combo  weight_combo_freqwt  ...  \
# 0              NaN      0.277188              19240.0  ...
# 1          70707.0      1.020621              70841.0  ...
# 2          56121.0      0.810074              56227.0  ...
# 3          98110.0      0.418556              29052.0  ...
# 4          67652.0      0.976522              67781.0  ...
#
#    hcm2017q24_met_through_family hcm2017q24_met_through_friend  \
# 0                             no                            no
# ...

# %%
df.describe()
# Out:
#             CaseID    CASEID_NEW      weight1  weight1_freqwt     weight2  \
# count  3510.000000  3.510000e+03  2994.000000     2994.000000  551.000000
# mean   2121.318803  2.181073e+06     0.999999    78337.460938    1.000003
# std    1241.582562  6.401295e+05     0.285004    22326.515625    0.908374
# min       2.000000  5.300100e+04     0.264700    20736.000000    0.190300
# 25%    1040.250000  1.825512e+06     0.808000    63297.000000    0.519650
# 50%    2118.500000  2.282692e+06     0.943900    73943.000000    0.713300
# 75%    3189.750000  2.759544e+06     1.142650    89512.250000    1.134700
# max    4311.000000  2.972135e+06     2.671000   209239.000000    7.797400
#
#           weight1a  weight1a_freqwt  weight_combo  weight_combo_freqwt  \
# count  3110.000000      3110.000000   3510.000000          3510.000000
# mean      1.000001     78337.601562      1.000000         69410.132812
# std       0.289889     22709.197266      0.437515         30367.960938
# ...

# %% [markdown]
# ### Chosen features

# %%
num_feature1 = 'w6_q16'  # how many relatives see in person each month
num_feature2 = 'time_from_met_to_rel'  # Time from meeting to relationship
cat_feature1 = 'ppgender'  # Gender
cat_feature2 = 'ppwork'  # Current Employment Status
label = 'S1'  # Are you married?

# %%
df[num_feature1].describe()
# Out:
# count    3367.000000
# mean        3.463914
# std         5.109420
# min         0.000000
# 25%         0.000000
# 50%         2.000000
# 75%         5.000000
# max        50.000000
# Name: w6_q16, dtype: float64

# %%
df[num_feature2].describe()
# Out:
# count    3263.000000
# mean        1.597072
# std         4.361366
# min         0.000000
# 25%         0.000000
# 50%         0.166748
# 75%         1.083252
# max        54.750000
# Name: time_from_met_to_rel, dtype: float64

# %%
df[cat_feature1].describe()
# Out:
# count       3510
# unique         2
# top       Female
# freq        1764
# Name: ppgender, dtype: object

# %%
df[cat_feature2].describe()  # From the same town
# Out:
# count                             3510
# unique                               7
# top       Working - as a paid employee
# freq                              1968
# Name: ppwork, dtype: object

# %%
df[label].describe()
# Out:
# count                  3510
# unique                    2
# top       Yes, I am Married
# freq                   2085
# Name: S1, dtype: object

# %% [markdown]
# #### Encoding data

# %%
def encode_cat(column):
    le = LabelEncoder()
    encoded_col = le.fit_transform(column)
    return le, encoded_col

# %%
df = df[[num_feature1, num_feature2, cat_feature1, cat_feature2, label]]
df = df.dropna()

le1, encoded_cat1 = encode_cat(df[cat_feature1])
le2, encoded_cat2 = encode_cat(df[cat_feature2])
df[cat_feature1] = encoded_cat1
df[cat_feature2] = encoded_cat2
df[label] = df[label].apply(lambda x: 1 if x == 'Yes, I am Married' else 0)
df.head()
# Out:
#    w6_q16  time_from_met_to_rel  ppgender  ppwork S1
# 0     1.0              0.000000         1       5  0
# 1     1.0             12.250000         0       3  1
# 2     0.0              0.416748         1       5  1
# 3     0.0              1.083252         0       3  0
# 4     0.0              0.083252         0       5  1

# %%
df.describe()
# Out:
#             w6_q16  time_from_met_to_rel     ppgender       ppwork
# count  3247.000000           3247.000000  3247.000000  3247.000000
# mean      3.444410              1.600347     0.493379     4.312904
# std       5.107885              4.370544     0.500033     1.453753
# min       0.000000              0.000000     0.000000     0.000000
# 25%       0.000000              0.000000     0.000000     4.000000
# 50%       2.000000              0.166748     0.000000     5.000000
# 75%       5.000000              1.083252     1.000000     5.000000
# max      50.000000             54.750000     1.000000     6.000000

# %% [markdown]
# #### Train / test split

# %%
X = df.drop(label, axis=1)
y = df[label]
train_X, test_X, train_y, test_y = train_test_split(X, y, random_state=seed)

# %% [markdown]
# ## Model training and validation

# %%
model = XGBClassifier()
model.fit(train_X.values, train_y.values)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
pred_y = model.predict(test_X.values)
score = accuracy_score(pred_y, test_y.values)
print(f'Accuracy: {(score*100):.2f}%')
# Out:
# Accuracy: 64.04%

# %% [markdown]
# ## Plotting

# %% [markdown]
# #### Plotting functions

# %%
def calculate_ICE(model, df, feature, npoints, center):
    f_min, f_max = df[feature].min(), df[feature].max()
    f_idx = df.columns.get_loc(feature)
    samples = df.values
    grid_values = np.linspace(f_min, f_max, npoints)
    all_preds = np.zeros(shape=(samples.shape[0], npoints))
    for i, val in enumerate(grid_values):
        samples[:, f_idx] = val
        preds = model.predict_proba(samples)[:, 1]
        all_preds[:, i] = preds
        
    if center:
        all_preds = all_preds - np.expand_dims(all_preds[:, 0], axis=1)
    return grid_values, all_preds


def calculate_ALE(model, df, feature, npoints):
    f_min, f_max = df[feature].min(), df[feature].max() 
    f_idx = df.columns.get_loc(feature)
    grid_values = np.linspace(f_min, f_max, 50)
    accumulated_effects = [0]
    
    for i in range(npoints-1):
        val_a, val_b = grid_values[i], grid_values[i+1]
        samples = df[(df[feature] >= val_a) & (df[feature] < val_b)].values
        samples[:, f_idx] = val_a
        if len(samples) == 0:
            accumulated_effects.append(accumulated_effects[-1])
        else:
            preds_a = model.predict_proba(samples)[:, 1]
            samples[:, f_idx] = val_b
            preds_b = model.predict_proba(samples)[:, 1]
            local_effect = np.mean(preds_b - preds_a)
            acc_loc_effect = accumulated_effects[-1] + local_effect
            accumulated_effects.append(acc_loc_effect)
    
    return grid_values, accumulated_effects


def plot_partial_dependency(model, df, features, npoints):
    if isinstance(npoints, int) and isinstance(features, str):
        npoints = [npoints]
        features = [features]
    assert len(npoints) == len(features)    
    
    fig, axes = plt.subplots(nrows=1, ncols=len(features), figsize=(15, 6))
    for i, (feature, n) in enumerate(zip(features, npoints)):
        grid_values, ice_values = calculate_ICE(model, df, feature, n, center=False)
        pd_line = np.mean(ice_values, axis=0)
        axes[i].plot(grid_values, pd_line, linewidth=4)
        axes[i].set_title(f'PD plot for {feature}')
      
    

def plot_ICE(model, df, features, npoints, center=False, show_pd=False):
    if isinstance(npoints, int) and isinstance(features, str):
        npoints = [npoints]
        features = [features]
    assert len(npoints) == len(features)    

    fig, axes = plt.subplots(nrows=1, ncols=len(features), figsize=(15, 6))
    for i, (feature, n) in enumerate(zip(features, npoints)):
        grid_values, ice_values = calculate_ICE(model, df, feature, n, center)
        for ice in ice_values:
            axes[i].plot(grid_values, ice, color='black', alpha=0.1)
        
        axes[i].set_title(f'ICE plot for {feature}')
        if show_pd:
            pd_line = np.mean(ice_values, axis=0)
            axes[i].plot(grid_values, pd_line, color='yellow', linewidth=7)
            
            
def plot_ALE(model, df, features, npoints):
    if isinstance(npoints, int) and isinstance(features, str):
        npoints = [npoints]
        features = [features]
    assert len(npoints) == len(features)   
    
    fig, axes = plt.subplots(nrows=1, ncols=len(features), figsize=(15, 6))
    for i, (feature, n) in enumerate(zip(features, npoints)):
        grid_values, ale_values = calculate_ALE(model, df, feature, n)
        axes[i].plot(grid_values, ale_values, linewidth=5)
        axes[i].set_title(f'ALE plot for {feature}')

# %% [markdown]
# ### Individual Conditional Expectation Plots
# #### Normal

# %%
plot_ICE(model, train_X, [num_feature1, num_feature2], [50, 50], center=False, show_pd=True)

# %% [markdown]
# #### Centered

# %%
plot_ICE(model, train_X, [num_feature1, num_feature2], [50, 50], center=True, show_pd=True)

# %% [markdown]
# #### Partial Dependency Plots

# %%
plot_partial_dependency(model, train_X, [num_feature1, num_feature2], [50, 50])

# %% [markdown]
# #### Accumulated Local Effect Plots

# %%
plot_ALE(model, train_X, [num_feature1, num_feature2], [50, 50])

# %% [markdown]
# ## Wnioski
#
# Porównane zostały wykresy PD oraz ALE dla zmiennych
# * 'w6_q16':  liczba spotykanych krewnych w miesiącu - wykresy po lewej
# * 'time_from_met_to_rel':  Czas od spotkania do związku - wykresy po prawej
#
# <br>
# Dla zmiennej 'w6_q16' wykresy PD i ALE zachowują się tak samo co świadczy, że ta zmienna nie jest skolerowana z pozostałymi.
# <br>
# Natomiast wykresy dla zmiennej 'time_from_met_to_rel' wyraźnie różnią sie tylko w przedziale [30-36] co może oznaczać, że w danym przedziale występuje jakaś anomalia.
